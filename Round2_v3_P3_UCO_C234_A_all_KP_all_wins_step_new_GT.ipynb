# %% [markdown]
# <a href="https://colab.research.google.com/github/margaretxie/Test_Paper3_with_UCO/blob/main/Round2_v3_P3_UCO_C234_A_all_KP_all_wins_step_new_GT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#test paper 3 - the HK one - with UCO dataset (only cam234, not cam 0 1, total 1296 videos )

# Paper 3 - https://link.springer.com/article/10.1007/s13755-023-00258-3  -skeleton based repeptition count method
# The paper's code - webpage: https://github.com/YuChengHSU/repetition-counting/tree/main

# UCO dataset [paper20] - downloaded from  http://rabinf24.uco.es/avaphy/    (Outlook Emailed got access )

## Round2_v3_P3_UCO_C234_A_all_KP_all_wins256_step1_new_GT - based on Round2-v2
## Round2 - v2_P3_UCO_C234_A16_KP[12, 14, 16]_wins256_step1_new_GT-based on Round2-v1
## Round2 - v1_P3_UCO_C234_A16_KP[12, 14, 16, 24, 26, 28]_wins256_step1_new_GT-based on v12 and round2_v0
## Round2 - v0 -get the Updated GT
## Round2 - have new groundtruth data

# v18: same as v17, only not 3 picked KPs but 1 KP - 29
# v17: same as v16, only not 33 KP but 3 picked KPs [25, 29, 31]
# v16: only UCO-Action1 (27 person, all ground truth are 4, except person 13's three records are 5), wins= 256, step = 125, KP 33, for comparing with V17, 3 picked KPs

# v14: v13_based, testing action 16 with selection2KPs, with obo & mae, with changing steps to 125
# v13: v9_v10_v11 based, for testing action 16 with hand picked KPs, with final obo & mae

# v12: v9_based, for testing action 16

# v9: v6_based,for testing KPselection- only 81 videos of action 16 "a16", and only with KPs from 13-22 (10 KPs)

# v8: v4_based, 33KPs_obo, mea by type
# v7: v3_based, 33KPs_ merge_estimated_n_groundtrue_count
# v6: v2_based, apply original paper3 model (using whole 33 KPs)
# v5: average KP used, popular KPs analyst
# v4: calculate obo, mea according to action types (1-16)
# v3: merge_estimated_n_groundtrue_count
# v2: apply paper3's model to filtered KPs which visibility >=threshold
# v1: extract each videos' KPs  (this code only for half cameras (2,3,4))
# v0: framework of looping all the .mp4 files, with name PnAn (Person*Action*)#

# Setup
v="R2_V3"

# Import necessary libraries
from google.colab import drive
import pandas as pd
import numpy as np
import os
import subprocess
from datetime import datetime
import pytz

# Mount Google Drive
drive.mount('/content/drive')

results = []

base_path = '/content/drive/My Drive/repetition_dataset/UCO/extracedKP_npy_cam234'
KP33_xyz_path = '/content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz'
#save_path = '/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a16_only'
save_path = '/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth'
groundtruth = '/content/drive/My Drive/repetition_dataset/UCO/merged_UCO/0_Manually check groud truth number_D.xlsx'  # real ground truth table
df = pd.read_excel(groundtruth)

f=25 # frame rate

wins = "256"
step = "1"

a = 'all_As'

#a = "a16"

# # KP - hand picked
# kp_indices = [12, 14, 16]

# Generating keypoint indices for the range 0-32
kp_indices = list(range(33))  # all 33 KPs

# FUNCTION for getting the UCO dataset real ground truth
import re

#base_path = '/content/gdrive/My Drive/repetition_dataset/UCO/merged_UCO/clips_mp4'


def get_count_from_excel(video_name, df):
    # Parse person number and action number from video name
    match = re.match(r'p(\d+)a(\d+)c', video_name)
    if not match:
        raise ValueError(f"Invalid video name format: {video_name}")

    person_number = int(match.group(1))  # Extracted person number
    action_number = match.group(2)  # Extracted action number as string to match column name format

    # Construct the column name in the format 'A2', 'A3', etc.
    action_column = f'A{action_number}'

    # Fetch the count from the DataFrame
    try:
        count = df.loc[df['Person'] == person_number, action_column].values[0]
    except KeyError:
        raise ValueError(f"Action code '{action_column}' not found in the Excel file.")
    except IndexError:
        raise ValueError(f"Person number '{person_number}' not found in the Excel file.")

    return count

# testing
video_name = "p1a12c3"
count = get_count_from_excel(video_name, df)
print(f'The count for {video_name} is: {count}')


def get_modified_filename(filename):
    # Find the position of the last underscore
    last_underscore_index = filename.rfind('_')
    # Extract the part of the filename after the last underscore
    if last_underscore_index != -1:
        new_filename = filename[last_underscore_index + 1:]
    else:
        new_filename = filename
    return new_filename


# Ensure the output directory exists
if not os.path.exists(save_path):
    os.makedirs(save_path)

# Function to process videos
def process_videos(base_path, kp_indices):
    for root, dirs, files in os.walk(base_path):
        for file in files:
            #if a in file:  # only a action
            if True:  # all the actions
                video_name = get_modified_filename(file)
                video_name = video_name.replace('.mp4', '.npy')
              #  print(f"Processing video: {video_name}")
                file_path = os.path.join(root, file)
                print(f"Processing {file_path}")
                data = np.load(file_path)

                # Use only selected KP
                filtered_data = data[:, kp_indices, :]

                # Save filtered data to a temporary .npy file
                temp_output_path = os.path.join(save_path, 'temp_filtered_data.npy')
                np.save(temp_output_path, filtered_data)

                # Prepare the command to run the external Python script with the necessary arguments
                command = [
                    "python", "rep-count.py",
                    "--data", temp_output_path,
                    "-j", str(len(kp_indices)),
                    "-d", "3",  # Only three dimensions are considered (x, y, z)
                    "-f", str(f),
                    "--wins", wins, #"256",
                    "--noverlap", step #"1"
                ]

                # Execute the command and capture the output
                try:
                    result = subprocess.run(command, check=True, capture_output=True, text=True)
                    output = result.stdout.strip()
                    estimated_count = int(output.split()[-1])  # Parse the count from the output
                    print("Output:", output)
                except subprocess.CalledProcessError as e:
                    print("Failed to execute command:", e)
                    print("Error output:", e.stderr)
                    estimated_count = None

                # get groundtruth
                count = get_count_from_excel(video_name, df)


                # Append results to the list
                results.append([video_name, len(kp_indices), estimated_count, count, data.shape[0]])


process_videos(KP33_xyz_path, kp_indices)

# Save the estimated counts of the filtered videos
current_time_str = datetime.now(pytz.timezone('America/New_York')).strftime('%Y%m%d%I%M%p').lower()

file_name = f"{v}_Cam234_output_{a}_{wins}_{step}.csv"
output_csv_path = os.path.join(save_path, file_name)

results_df = pd.DataFrame(results, columns=['Video Name', 'KP Numbers', 'Estimated Count', 'GT Count','Frame Number'])
results_df.to_csv(output_csv_path, index=False)

print("\n########First five rows of results_df:\n")
print(results_df.head(5))

print("\n########Last five rows of results_df:\n")
print(results_df.tail(5))

print(f"\nResults saved to {output_csv_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# The count for p1a12c3 is: 14.0
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a06c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a06c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a07c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a07c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a07c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a08c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a08c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 9
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a08c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a09c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a09c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a09c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a10c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a10c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a10c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a11c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a11c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a11c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a12c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a12c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 19
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a12c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 16
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a13c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a13c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a13c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 3
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 12
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a15c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a15c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a15c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a16c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 14
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a16c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a16c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 17
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a01c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a01c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a01c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a02c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a02c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a02c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a03c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a03c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a03c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a04c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a04c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a04c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 9
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a05c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a05c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a05c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a06c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a06c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a06c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a07c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a07c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a07c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a08c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a08c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a08c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a09c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a09c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a09c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a10c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a10c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a10c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a11c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a11c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a11c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a12c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a12c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a12c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a13c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a13c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a13c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a15c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a15c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a15c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 9
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a16c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a16c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a16c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 9
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a01c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a01c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a01c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a02c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a02c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a02c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a03c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a03c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a03c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a04c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a04c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a04c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a05c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a05c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a05c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a06c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a06c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a06c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a07c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a07c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a07c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a08c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a08c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a08c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 10
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a09c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a09c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a09c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a10c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a10c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 11
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a10c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a11c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a11c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a11c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a12c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 16
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a12c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 16
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a12c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a13c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a13c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a13c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a15c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a15c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a15c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a16c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 16
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a16c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 16
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a16c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 20
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a01c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a01c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a01c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a02c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a02c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a02c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a03c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a03c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a03c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a04c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a04c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a04c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a05c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a05c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a05c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a06c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a06c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a06c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a07c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a07c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a07c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a08c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a08c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a08c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a09c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a09c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a09c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a10c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a10c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 11
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a10c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a11c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a11c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a11c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a12c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 11
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a12c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a12c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 12
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a13c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a13c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a13c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a14c2.npy
# ...
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a05c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a05c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a05c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a06c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a06c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a06c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a07c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a07c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a07c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a08c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a08c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a08c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a09c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a09c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a09c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a10c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a10c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a10c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a11c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a11c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a11c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a12c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 14
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a12c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 10
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a12c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 14
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a13c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a13c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a13c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a15c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a15c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a15c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a16c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a16c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a16c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a01c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a01c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a01c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a02c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a02c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a02c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a03c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a03c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a03c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a04c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a04c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a04c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a05c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a05c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a05c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a06c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/temp_filtered_data.npy', j=33, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
#
# ########First five rows of results_df:
#
#      Video Name  KP Numbers  Estimated Count  GT Count  Frame Number
# 0  p12a06c3.npy          33                4       4.0           797
# 1  p12a06c4.npy          33                4       4.0           798
# 2  p12a07c2.npy          33                5       5.0           703
# 3  p12a07c3.npy          33                8       5.0           704
# 4  p12a07c4.npy          33                5       5.0           704
#
# ########Last five rows of results_df:
#
#         Video Name  KP Numbers  Estimated Count  GT Count  Frame Number
# 1290  p12a04c4.npy          33                4       4.0           774
# 1291  p12a05c2.npy          33                5       4.0           647
# 1292  p12a05c3.npy          33                5       4.0           647
# 1293  p12a05c4.npy          33                5       4.0           647
# 1294  p12a06c2.npy          33                4       4.0           798
#
# Results saved to /content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/R2_V3_Cam234_output_all_As_256_1.csv

# %%
a = 'all_As'
# Save the estimated counts of the filtered videos
current_time_str = datetime.now(pytz.timezone('America/New_York')).strftime('%Y%m%d%I%M%p').lower()

file_name = f"{v}_Cam234_output_{a}_{wins}_{step}.csv"
output_csv_path = os.path.join(save_path, file_name)

results_df = pd.DataFrame(results, columns=['Video Name', 'KP Numbers', 'Estimated Count', 'GT Count','Frame Number'])
results_df.to_csv(output_csv_path, index=False)

print("\n########First five rows of results_df:\n")
print(results_df.head(5))

print("\n########Last five rows of results_df:\n")
print(results_df.tail(5))

print(f"\nResults saved to {output_csv_path}")
# Out:
# ########First five rows of results_df:
#
#      Video Name  KP Numbers  Estimated Count  GT Count  Frame Number
# 0  p12a06c3.npy          33                4       4.0           797
# 1  p12a06c4.npy          33                4       4.0           798
# 2  p12a07c2.npy          33                5       5.0           703
# 3  p12a07c3.npy          33                8       5.0           704
# 4  p12a07c4.npy          33                5       5.0           704
#
# ########Last five rows of results_df:
#
#         Video Name  KP Numbers  Estimated Count  GT Count  Frame Number
# 1290  p12a04c4.npy          33                4       4.0           774
# 1291  p12a05c2.npy          33                5       4.0           647
# 1292  p12a05c3.npy          33                5       4.0           647
# 1293  p12a05c4.npy          33                5       4.0           647
# 1294  p12a06c2.npy          33                4       4.0           798
#
# Results saved to /content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/R2_V3_Cam234_output_all_As_256_1.csv

# %%
df = pd.read_csv(output_csv_path)

# Rename the 'Video Name' column to 'Name'
df.rename(columns={'Video Name': 'Name'}, inplace=True)

# # Add a new column '1 or 0' to show the record's performance
# df['count'] = 4

df['1 or 0'] = (abs(df['Estimated Count'] - df['GT Count']) <= 1).astype(int)


# Add a new column 'type' with the two numbers after the letter 'a' in the 'Name' values
df['type'] = df['Name'].apply(lambda x: x.split('a')[1][:2])


# Save the updated DataFrame to the CSV file
#df.to_csv(output_csv_path_2, index=False)
df.to_csv(output_csv_path, index=False)

print(f'\n the combined estimated and groundtruth counts file has been save to {output_csv_path}')
# Out:
#  the combined estimated and groundtruth counts file has been save to /content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/R2_V3_Cam234_output_all_As_256_1.csv

# %%
print(v)

kp_indices = list(range(33))

file_path = output_csv_path

# Correct comparison
if kp_indices == list(range(33)):
    KP_num = "33"
else:
  KP_num = str(len(kp_indices))

print(KP_num)

new_file_path = os.path.join(save_path, f'{v}_A:{a}__KP:{str(len(kp_indices))}__{wins}__{step}.csv' )

# Load the data
data = pd.read_csv(file_path)

# calculate OBO Correct Classification Rate
def calculate_obo(data):
    # Calculate OBO as the rate of correct classifications
    obo_correct = (abs(data['Estimated Count'] - data['GT Count']) <= 1).mean()
    return obo_correct  # Higher is better (correct classification rate)

# Function to calculate MAE
def calculate_mae(data):
    conditions = data['GT Count'] != 0
    data.loc[conditions, 'MAE'] = abs(data['Estimated Count'] - data['GT Count']) / data['GT Count']
    data.loc[~conditions, 'MAE'] = np.nan  # Treat division by zero cases as NaN
    return data['MAE'].mean(skipna=True)

# Calculating metrics for each type and overall
results = []
for type_ in data['type'].unique():
    type_data = data[data['type'] == type_].copy()
    obo_correct = calculate_obo(type_data)
    mae = calculate_mae(type_data)
    record_count = type_data.shape[0]
    results.append({'Type': type_, 'OBO (Higher Better)': round(obo_correct, 2), 'MAE (Lower Better)': round(mae, 2), 'Record Count': record_count})

# Convert to DataFrame
results_df = pd.DataFrame(results)

# Calculate overall metrics
overall_obo = calculate_obo(data)
overall_mae = calculate_mae(data)

# Append overall metrics to the DataFrame using pd.concat
overall_df = pd.DataFrame([{'Type': 'Overall', 'OBO (Higher Better)': round(overall_obo, 2), 'MAE (Lower Better)': round(overall_mae, 2), 'Record Count': data.shape[0]}])
results_df = pd.concat([results_df, overall_df], ignore_index=True)

# Sort the DataFrame by OBO Correct Rate in ascending order
results_df = results_df.sort_values('OBO (Higher Better)', ascending=True)

# Print the sorted DataFrame before saving

if kp_indices == list(range(33)):
  kp_indices = "All 33KPs"

print('')
print('')
print(f'                 {v}_UCO_Paper3 CAM234 Type:{a}' )
print('')
print(f'          KP: {kp_indices} wins={wins} step={step} f=25')
print('=============================================================================')
print('')
print(results_df)

# Save to new CSV file
results_df.to_csv(new_file_path, index=False)

print(f'\n the metrics file has been save to {new_file_path}')
# Out:
# R2_V3
# 33
#
#
#                  R2_V3_UCO_Paper3 CAM234 Type:all_As
#
#           KP: All 33KPs wins=256 step=1 f=25
# =============================================================================
#
#        Type  OBO (Higher Better)  MAE (Lower Better)  Record Count
# 6        12                 0.42                0.33            81
# 10       16                 0.44                0.29            81
# 14        4                 0.60                0.41            81
# 2         8                 0.60                0.40            81
# 4        10                 0.69                0.43            81
# 15        5                 0.73                0.31            81
# 16  Overall                 0.74                0.27          1295
# 8        14                 0.75                0.33            81
# 9        15                 0.79                0.26            81
# 11        1                 0.80                0.23            81
# 0         6                 0.82                0.24            80
# 5        11                 0.83                0.22            81
# 1         7                 0.83                0.19            81
# 12        2                 0.85                0.22            81
# 7        13                 0.85                0.14            81
# 13        3                 0.86                0.17            81
# 3         9                 0.89                0.22            81
#
#  the metrics file has been save to /content/drive/My Drive/repetition_dataset/UCO/results_round2_realGroundTruth/R2_V3_A:all_As__KP:33__256__1.csv
