# %% [markdown]
# <a href="https://colab.research.google.com/github/margaretxie/Test_Paper3_with_UCO/blob/main/UCO_v9_Manual_selectedKP_vs__Full_KP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#test paper 3 - the HK one - with UCO dataset (only cam234, not cam 0 1, total 1296 videos )

# Paper 3 - https://link.springer.com/article/10.1007/s13755-023-00258-3  -skeleton based repeptition count method
# The paper's code - webpage: https://github.com/YuChengHSU/repetition-counting/tree/main

# UCO dataset [paper20] - downloaded from  http://rabinf24.uco.es/avaphy/    (Outlook Emailed got access )

# v9: v6_based,for testing KPselection- only 81 videos of action 14 "a14", and only with KPs from 13-22 (10 KPs)

# v8: v4_based, 33KPs_obo, mea by type
# v7: v3_based, 33KPs_ merge_estimated_n_groundtrue_count
# v6: v2_based, apply original paper3 model (using whole 33 KPs)
# v5: average KP used, popular KPs analyst
# v4: calculate obo, mea according to action types (1-16)
# v3: merge_estimated_n_groundtrue_count
# v2: apply paper3's model to filtered KPs which visibility >=threshold
# v1: extract each videos' KPs  (this code only for half cameras (2,3,4))
# v0: framework of looping all the .mp4 files, with name PnAn (Person*Action*)#



# Setup
v="V9"

# Import necessary libraries
from google.colab import drive
import pandas as pd
import numpy as np
import os
import subprocess
from datetime import datetime
import pytz

# Mount Google Drive
drive.mount('/content/drive')

results = []

base_path = '/content/drive/My Drive/repetition_dataset/UCO/extracedKP_npy_cam234'
KP33_xyz_path = '/content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz'
save_path = '/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only'

f=25 # frame rate


def get_modified_filename(filename):
    # Find the position of the last underscore
    last_underscore_index = filename.rfind('_')
    # Extract the part of the filename after the last underscore
    if last_underscore_index != -1:
        new_filename = filename[last_underscore_index + 1:]
    else:
        new_filename = filename
    return new_filename



# Ensure the output directory exists
if not os.path.exists(save_path):
    os.makedirs(save_path)

# Function to process videos
def process_videos(base_path, kp_indices):
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if 'a14' in file:
                video_name = get_modified_filename(file)
                video_name = video_name.replace('.mp4', '.npy')
              #  print(f"Processing video: {video_name}")
                file_path = os.path.join(root, file)
                print(f"Processing {file_path}")
                data = np.load(file_path)

                # Use only KP 13-22
                filtered_data = data[:, kp_indices, :]

                # Save filtered data to a temporary .npy file
                temp_output_path = os.path.join(save_path, 'temp_filtered_data.npy')
                np.save(temp_output_path, filtered_data)

                # Prepare the command to run the external Python script with the necessary arguments
                command = [
                    "python", "rep-count.py",
                    "--data", temp_output_path,
                    "-j", str(len(kp_indices)),
                    "-d", "3",  # Only three dimensions are considered (x, y, z)
                    "-f", str(f),
                    "--wins", "256",
                    "--noverlap", "1"
                ]

                # Execute the command and capture the output
                try:
                    result = subprocess.run(command, check=True, capture_output=True, text=True)
                    output = result.stdout.strip()
                    estimated_count = int(output.split()[-1])  # Parse the count from the output
                    print("Output:", output)
                except subprocess.CalledProcessError as e:
                    print("Failed to execute command:", e)
                    print("Error output:", e.stderr)
                    estimated_count = None

                # Append results to the list
                results.append([video_name, len(kp_indices), estimated_count, data.shape[0]])

# KP indices for KP 13 to KP 22 (0-based indexing)
kp_indices = list(range(13, 23))

process_videos(KP33_xyz_path, kp_indices)

# Save the estimated counts of the filtered videos
current_time_str = datetime.now(pytz.timezone('America/New_York')).strftime('%Y%m%d%I%M%p').lower()
file_name = f"{v}_Cam234_output_{current_time_str}.csv"
output_csv_path = os.path.join(save_path, file_name)

results_df = pd.DataFrame(results, columns=['Video Name', 'KP Numbers', 'Estimated Count', 'Frame Number'])
results_df.to_csv(output_csv_path, index=False)

print("\n########First five rows of results_df:\n")
print(results_df.head(5))

print("\n########Last five rows of results_df:\n")
print(results_df.tail(5))

print(f"\nResults saved to {output_csv_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p12a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p13a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p14a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p15a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p16a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p16a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p16a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p17a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p17a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p17a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 9
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p18a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p18a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p18a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p19a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p19a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p19a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p20a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 11
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p20a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 12
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p20a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p21a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p21a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p21a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 11
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p22a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p22a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p22a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p23a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p23a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p23a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p24a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p24a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p24a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p25a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p25a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p25a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p26a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 14
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p26a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p26a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p0a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 14
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p0a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p0a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p1a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p1a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p1a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p2a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p2a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p2a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p3a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p3a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p3a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 9
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p4a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p4a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 8
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p4a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 6
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p5a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p5a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 10
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p5a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p6a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 10
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p6a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p6a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p7a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p7a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p7a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p8a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 12
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p8a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p8a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 5
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p9a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p9a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 10
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p9a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p10a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p10a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 7
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p10a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a14c2.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a14c3.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
# Processing /content/drive/My Drive/repetition_dataset/UCO/npy_cam234_33KPs_xyz/33KP_xyz_p11a14c4.npy
# Output: Namespace(data='/content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/temp_filtered_data.npy', j=10, d=3, f=25, wins=256, noverlap=1)
# Estimated count 4
#
# ########First five rows of results_df:
#
#      Video Name  KP Numbers  Estimated Count  Frame Number
# 0  p12a14c2.npy          10                5           628
# 1  p12a14c3.npy          10                5           628
# 2  p12a14c4.npy          10                5           627
# 3  p13a14c2.npy          10                4           503
# 4  p13a14c3.npy          10                4           504
#
# ########Last five rows of results_df:
#
#       Video Name  KP Numbers  Estimated Count  Frame Number
# 76  p10a14c3.npy          10                7           487
# 77  p10a14c4.npy          10                4           486
# 78  p11a14c2.npy          10                4           498
# 79  p11a14c3.npy          10                4           498
# 80  p11a14c4.npy          10                4           498
#
# Results saved to /content/drive/My Drive/repetition_dataset/UCO/results_cam234_a14_only/V9_Cam234_output_202406191238pm.csv
